# %% [markdown]
# # Data Preproccesing Basics
#
# ## LivWell Dataset: Women and their Well-being for 52 Countries
# #### Introduction to Python
#
# #### <a href="https://www.linkedin.com/in/fayshaw/">Fay Shaw</a>
# MIT WIT ERG
# September 23, 2026
#
# Together, we will explore the LivWell dataset from the Belmin et al's 2022 Nature paper <a href=" https://www.nature.com/articles/s41597-022-01824-2"> LivWell: a sub-national Dataset on the Living Conditions of Women and their Well-being for 52 Countries</a>. The authors constructed a longitudinal dataset using Demographic and Health Surveys (DHS), GDP data, and climate data for subnational regions for 1990 - 2019.
#
# *Figure 1: Flowchart representing the data processing steps to obtain LivWell. Orange: input data; green: indicators based on DHS data; blue: indicators based on gridded data; white: validation data.*
#
# <img src="https://media.springernature.com/full/springer-static/image/art%3A10.1038%2Fs41597-022-01824-2/MediaObjects/41597_2022_1824_Fig1_HTML.png" width="600"/>
#
#
#
# In this notebook, we will look at some of the DHS STAT data compare it to their data output.
#
# <img src="https://github.githubassets.com/assets/GitHub-Mark-ea2971cee799.png" width=30/>
# <a href="https://github.com/fayshaw/data_preprocessing">Github repository</a>
#
# This notebook is a simplification of the project <a href="https://github.com/fayshaw/data_preprocessing/blob/main/livwell.ipynb">Data Preprocessing Best Practices</a>

# %% [markdown]
# # 🎯 Goals for this session
# 1. Learn the context of the LivWell dataset.
# 2. Learn Python code to transform the raw data to compare to LivWell
#
# # 📚 Goals for different learners
# * 🌟 If you are new to Python, welcome!  Learn how to run colab files, read files, learn about dataframes.
# * 🧰 If you are familiar with dataframes and notebooks, here are some transformation tools.
# * 🐍 If you are a saavy Pythonista, check out the 🔎 *more to explore* prompts!  Combine different datasets together or challenge yourself to reproduce their R analysis code in Python!
#
# ## 🗂️ Files
# * Load LivWell dataset using urls: `livwell.csv` and `indicators.csv`
# * Load DHS STAT raw data: `STATcompilerExport_decision_power.csv`
#
# Both the DHS STAT and Global Mean data are found in the authors' <a href="https://gitlab.pik-potsdam.de/belmin/livwelldata-paper/-/tree/main/analysis/data/raw_data/validation_data?ref_type=heads"> validation data folder</a> on gitlab.

# %% [markdown]
# # 🤖 Hello world!
# I like Python because I find it faily readable as a programming langauge. You can run code in a notebook cell by clicking on the cell and pressing `Shift + Enter` or with the green ▶️ play button on the left.   Try it out below!

# %%
print("Hello, MIT WIT!")
# Out:
# Hello, MIT WIT!

# %% [markdown]
# # 💡 1. Learn the context by exploring the data
#
# ## Read files
# The first thing to do is to look at the the LivWell data.  We can open it in Excel and also read in the file using the package pandas.
#
# Input the file with `read_csv` and the filename.
#
# We assign it to the dataframe `livwell_df`, which is a dataframe.  A dataframe is tabular data with rows and columns.

# %%
import pandas as pd
livwell_df = pd.read_csv('https://zenodo.org/records/7277104/files/livwell.csv')

# %% [markdown]
# ## Explore the data
#
# Uses these functions to explor the dataFrame `df`
# * `df.shape`
# * `df.head()`
# * `df.columns`
#
# Using the function `livwell_df.shape` shows the number of rows and columns

# %%
livwell_df.shape
# Out:
# (1832, 409)

# %% [markdown]
# `livewell_df.head()` shows the first 5 rows.

# %%
livwell_df.head()
# Out:
#   country_name country_code  year  region_num_harmonized  \
# 0      Armenia          ARM  2000                      1
# 1      Armenia          ARM  2000                      2
# 2      Armenia          ARM  2000                      3
# 3      Armenia          ARM  2000                      4
# 4      Armenia          ARM  2000                      5
#
#   region_name_harmonized   SurveyId  interview_year_mean  \
# 0             Aragatsotn  AM2000DHS               2000.0
# 1                 Ararat  AM2000DHS               2000.0
# 2                Armavir  AM2000DHS               2000.0
# 3            Gegharkunik  AM2000DHS               2000.0
# 4                   Lori  AM2000DHS               2000.0
#
#    interview_month_mean  CMC_interview_mean  DM_age_mean  ...  \
# 0                  11.0             1210.53        30.71  ...
# 1                  11.0             1210.55        30.38  ...
# 2                  10.0             1210.43        31.10  ...
# 3                  11.0             1210.58        30.65  ...
# 4                  10.0             1210.43        31.57  ...
#
#    drought_spei03_n1_share36  drought_spei03_n1_share60  \
# 0                   0.388889                   0.316667
# 1                   0.416667                   0.316667
# 2                   0.361111                   0.300000
# 3                   0.416667                   0.316667
# 4                   0.388889                   0.316667
#
#    drought_spei03_n1.5_share12  drought_spei03_n1.5_share36  \
# 0                     0.333333                     0.250000
# 1                     0.333333                     0.277778
# 2                     0.333333                     0.250000
# 3                     0.250000                     0.194444
# 4                     0.333333                     0.222222
#
#    drought_spei03_n1.5_share60  drought_spei03_n2_share12  \
# 0                     0.166667                   0.083333
# 1                     0.233333                   0.083333
# 2                     0.166667                   0.083333
# 3                     0.166667                   0.083333
# 4                     0.150000                   0.083333
#
#    drought_spei03_n2_share36  drought_spei03_n2_share60       hdi       gdp_pc
# 0                   0.083333                       0.05  0.644083  2938.187500
# 1                   0.083333                       0.05  0.644127  3053.040283
# 2                   0.083333                       0.05  0.644415  3003.245605
# 3                   0.083333                       0.05  0.643942  2945.085449
# 4                   0.083333                       0.05  0.645256  2925.469727
#
# [5 rows x 409 columns]

# %% [markdown]
# To view the columns, use `livwell_df.columns`.

# %%
livwell_df.columns
# Out:
# Index(['country_name', 'country_code', 'year', 'region_num_harmonized',
#        'region_name_harmonized', 'SurveyId', 'interview_year_mean',
#        'interview_month_mean', 'CMC_interview_mean', 'DM_age_mean',
#        ...
#        'drought_spei03_n1_share36', 'drought_spei03_n1_share60',
#        'drought_spei03_n1.5_share12', 'drought_spei03_n1.5_share36',
#        'drought_spei03_n1.5_share60', 'drought_spei03_n2_share12',
#        'drought_spei03_n2_share36', 'drought_spei03_n2_share60', 'hdi',
#        'gdp_pc'],
#       dtype='object', length=409)

# %% [markdown]
# To look at the countries, look at the set of countries.

# %%
set(livwell_df['country_name'])
# Out:
# {'Armenia',
#  'Bangladesh',
#  'Benin',
#  'Bolivia',
#  'Burkina Faso',
#  'Burundi',
#  'Cambodia',
#  'Cameroon',
#  'Colombia',
#  'Congo Democratic Republic',
#  "Cote d'Ivoire",
#  'Egypt',
#  'Ethiopia',
#  'Gabon',
#  'Ghana',
#  'Guatemala',
#  'Guinea',
#  'Haiti',
#  'Honduras',
#  'India',
#  'Indonesia',
#  'Jordan',
#  'Kenya',
#  'Lesotho',
#  'Liberia',
#  'Madagascar',
#  'Malawi',
#  'Maldives',
#  'Mali',
#  'Morocco',
#  'Mozambique',
#  'Namibia',
#  'Nepal',
#  'Nicaragua',
#  'Niger',
#  'Nigeria',
#  'Pakistan',
#  'Peru',
#  'Philippines',
#  'Rwanda',
#  'Senegal',
#  'Sierra Leone',
#  'South Africa',
#  'Tajikistan',
#  'Tanzania',
#  'Timor-Leste',
#  'Togo',
#  'Turkey',
#  'Uganda',
#  'Vietnam',
#  'Zambia',
#  'Zimbabwe'}

# %% [markdown]
# ### Resources
# * <a href="https://realpython.com/pandas-python-explore-dataset/">Real Python dataframe resource</a>
# * <a href="https://pandas.pydata.org/Pandas_Cheat_Sheet.pdf">PyData Pandas cheat sheet</a>

# %% [markdown]
# ## Decoding the LivWell data
# What do the columns mean?  Look at `indicators.csv`

# %%
indicators_df = pd.read_csv("https://zenodo.org/records/7277104/files/indicators.csv")
indicators_df
# Out:
#                      indicator_category               indicator_code  \
# 0    Individual demographic information                  DM_age_mean
# 1    Individual demographic information               DM_age_15-19_p
# 2    Individual demographic information               DM_age_20-24_p
# 3    Individual demographic information               DM_age_25-29_p
# 4    Individual demographic information               DM_age_30-34_p
# ..                                  ...                          ...
# 260                             Drought  drought_spei03_n1.5_share36
# 261                             Drought  drought_spei03_n1.5_share60
# 262                             Drought    drought_spei03_n2_share12
# 263                             Drought    drought_spei03_n2_share36
# 264                             Drought    drought_spei03_n2_share60
#
#                                  indicator_description
# 0                                 Average age of women
# 1                      Women in age category 15-19 (%)
# 2                      Women in age category 20-24 (%)
# 3                      Women in age category 25-29 (%)
# 4                      Women in age category 30-34 (%)
# ..                                                 ...
# 260  Share of months in the past 36 months with dro...
# 261  Share of months in the past 60 months with dro...
# 262  Share of months in the past 12 months with dro...
# 263  Share of months in the past 36 months with dro...
# 264  Share of months in the past 60 months with dro...
#
# [265 rows x 3 columns]

# %% [markdown]
# Look at one column of data using the dataframe `df` and the column name `col`: `df['col']`.  You can use `set()` to find the set of values.

# %%
set(indicators_df['indicator_category'])
# Out:
# {'Decision power',
#  'Domestic Violence',
#  'Drought',
#  'Education',
#  'Energy and information',
#  'Energy and information – Household level',
#  'Energy and information – per urban/rural area',
#  'Fertility preferences',
#  'Fertility – complex indicators',
#  'Health',
#  'Health – Birth level',
#  'Household Wealth',
#  'Household characteristics – Household level',
#  'Household characteristics – Womens level',
#  'Household demographics – Household level',
#  'Household household demographics – Household level',
#  'Individual demographic information',
#  'Nutrition',
#  'Precipitation',
#  'Reproductive health and fertility',
#  'Socio-economic indicators',
#  'Standardized Precipitation Evapotranspiration Index (SPEI)',
#  'Temperature',
#  'Work status'}

# %%
# Find unique countries
livwell_df['country_name'].unique()
# Out:
# array(['Armenia', 'Burundi', 'Benin', 'Burkina Faso', 'Bangladesh',
#        'Bolivia', "Cote d'Ivoire", 'Cameroon',
#        'Congo Democratic Republic', 'Colombia', 'Egypt', 'Ethiopia',
#        'Gabon', 'Ghana', 'Guinea', 'Guatemala', 'Honduras', 'Haiti',
#        'Indonesia', 'India', 'Jordan', 'Kenya', 'Cambodia', 'Liberia',
#        'Lesotho', 'Morocco', 'Madagascar', 'Maldives', 'Mali',
#        'Mozambique', 'Malawi', 'Namibia', 'Niger', 'Nigeria', 'Nicaragua',
#        'Nepal', 'Pakistan', 'Peru', 'Philippines', 'Rwanda', 'Senegal',
#        'Sierra Leone', 'Togo', 'Tajikistan', 'Timor-Leste', 'Turkey',
#        'Tanzania', 'Uganda', 'Vietnam', 'South Africa', 'Zambia',
#        'Zimbabwe'], dtype=object)

# %%
# The length of the set of
len(livwell_df['country_name'].unique())
# Out:
# 52

# %% [markdown]
# ## Filter to get data for one country

# %%
# Choose one column and check if the value is Armenia.
livwell_df['country_name'] == 'Armenia'
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
#         ...
# 1827    False
# 1828    False
# 1829    False
# 1830    False
# 1831    False
# Name: country_name, Length: 1832, dtype: bool

# %%
# Create a new dataframe livwell_armenia for that country
livwell_armenia = livwell_df[livwell_df['country_name'] == 'Armenia']

# Years with survey data
print("years: " , set(livwell_armenia['year']))

# Regions in Armenia
print("regions: ", set(livwell_armenia['region_name_harmonized']))
livwell_armenia.head(12)
# Out:
# years:  {2000, 2010, 2016, 2005}
# regions:  {'Ararat', 'Aragatsotn', 'Tavush', 'Armavir', 'Syunik', 'Lori', 'Vayots Dzor', 'Yerevan', 'Kotayk', 'Gegharkunik', 'Shirak'}
#    country_name country_code  year  region_num_harmonized  \
# 0       Armenia          ARM  2000                      1
# 1       Armenia          ARM  2000                      2
# 2       Armenia          ARM  2000                      3
# 3       Armenia          ARM  2000                      4
# 4       Armenia          ARM  2000                      5
# 5       Armenia          ARM  2000                      6
# 6       Armenia          ARM  2000                      7
# 7       Armenia          ARM  2000                      8
# 8       Armenia          ARM  2000                      9
# 9       Armenia          ARM  2000                     10
# 10      Armenia          ARM  2000                     11
# 11      Armenia          ARM  2005                      1
#
#    region_name_harmonized   SurveyId  interview_year_mean  \
# 0              Aragatsotn  AM2000DHS               2000.0
# 1                  Ararat  AM2000DHS               2000.0
# 2                 Armavir  AM2000DHS               2000.0
# 3             Gegharkunik  AM2000DHS               2000.0
# 4                    Lori  AM2000DHS               2000.0
# 5                  Kotayk  AM2000DHS               2000.0
# 6                  Shirak  AM2000DHS               2000.0
# 7                  Syunik  AM2000DHS               2000.0
# 8             Vayots Dzor  AM2000DHS               2000.0
# 9                  Tavush  AM2000DHS               2000.0
# 10                Yerevan  AM2000DHS               2000.0
# 11             Aragatsotn  AM2005DHS               2005.0
#
#     interview_month_mean  CMC_interview_mean  DM_age_mean  ...  \
# 0                   11.0             1210.53        30.71  ...
# 1                   11.0             1210.55        30.38  ...
# 2                   10.0             1210.43        31.10  ...
# 3                   11.0             1210.58        30.65  ...
# 4                   10.0             1210.43        31.57  ...
# 5                   10.0             1210.48        31.15  ...
# 6                   10.0             1210.43        31.80  ...
# 7                   10.0             1210.42        31.37  ...
# 8                   10.0             1210.41        31.69  ...
# 9                   10.0             1210.46        31.28  ...
# 10                  11.0             1210.58        31.37  ...
# 11                  10.0             1269.73        30.82  ...
#
#     drought_spei03_n1_share36  drought_spei03_n1_share60  \
# 0                    0.388889                   0.316667
# 1                    0.416667                   0.316667
# 2                    0.361111                   0.300000
# 3                    0.416667                   0.316667
# 4                    0.388889                   0.316667
# 5                    0.416667                   0.316667
# 6                    0.388889                   0.350000
# 7                    0.416667                   0.316667
# 8                    0.388889                   0.300000
# 9                    0.416667                   0.300000
# 10                   0.388889                   0.316667
# 11                   0.027778                   0.066667
#
#     drought_spei03_n1.5_share12  drought_spei03_n1.5_share36  \
# 0                      0.333333                     0.250000
# 1                      0.333333                     0.277778
# 2                      0.333333                     0.250000
# 3                      0.250000                     0.194444
# 4                      0.333333                     0.222222
# 5                      0.333333                     0.277778
# 6                      0.333333                     0.194444
# 7                      0.166667                     0.222222
# 8                      0.333333                     0.277778
# 9                      0.333333                     0.194444
# 10                     0.333333                     0.277778
# 11                     0.000000                     0.000000
#
#     drought_spei03_n1.5_share60  drought_spei03_n2_share12  \
# 0                      0.166667                   0.083333
# 1                      0.233333                   0.083333
# 2                      0.166667                   0.083333
# 3                      0.166667                   0.083333
# 4                      0.150000                   0.083333
# 5                      0.183333                   0.083333
# 6                      0.133333                   0.083333
# 7                      0.183333                   0.083333
# 8                      0.216667                   0.083333
# 9                      0.133333                   0.083333
# 10                     0.183333                   0.083333
# 11                     0.000000                   0.000000
#
#     drought_spei03_n2_share36  drought_spei03_n2_share60       hdi  \
# 0                    0.083333                   0.050000  0.644083
# 1                    0.083333                   0.050000  0.644127
# 2                    0.083333                   0.050000  0.644415
# 3                    0.083333                   0.050000  0.643942
# 4                    0.083333                   0.050000  0.645256
# 5                    0.083333                   0.050000  0.644000
# 6                    0.083333                   0.050000  0.645674
# 7                    0.055556                   0.066667  0.644479
# 8                    0.194444                   0.133333  0.643944
# 9                    0.083333                   0.050000  0.644377
# 10                   0.083333                   0.050000  0.644000
# 11                   0.000000                   0.000000  0.691954
#
#          gdp_pc
# 0   2938.187500
# 1   3053.040283
# 2   3003.245605
# 3   2945.085449
# 4   2925.469727
# 5   2918.557617
# 6   3053.684326
# 7   3086.177002
# 8   2969.261230
# 9   3000.003906
# 10  2918.557617
# 11  5305.916992
#
# [12 rows x 409 columns]

# %% [markdown]
# ## 🔎 More to explore with dataframes
# pandas DataFrame: https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.html
# * `df.describe()`
# * `df.dtypes`
# * `df['column'].value_counts()`

# %% [markdown]
# # 🚀 2. Transform raw dataset to compare to LivWell

# %% [markdown]
# ## Read the validation STAT file
#
# Read the data from the World Bank open data file that the authors used for validation `STATcompilerExport_decision_power.csv`
#
# 🔎 Notice that there `Unnamed` column names at the top along with NaN rows at the top and bottom

# %%
stat_decision_power_file = 'https://raw.githubusercontent.com/fayshaw/data_preprocessing/refs/heads/main/STATcompilerExport_decision_power.csv'
stat_power = pd.read_csv(stat_decision_power_file)
stat_power
# Out:
#                                             Unnamed: 0  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                              Country
# 3                                              Armenia
# 4                                              Armenia
# ..                                                 ...
# 723        Final say in making large purchases [Women]
# 724  Final say in visits to family, relatives, frie...
# 725  Women who decide themselves how their earnings...
# 726                       Wife earns more than husband
# 727  ICF, 2015. The DHS Program STATcompiler. Funde...
#
#                                             Unnamed: 1           Unnamed: 2  \
# 0                                                  NaN                  NaN
# 1                                                  NaN                  NaN
# 2                                               Survey       Characteristic
# 3                                          2015-16 DHS                Total
# 4                                          2015-16 DHS  Region : Aragatsotn
# ..                                                 ...                  ...
# 723  Percentage of women who say that they alone or...                  NaN
# 724  Percentage of women who say that they alone or...                  NaN
# 725  Percentage of currently married or in union wo...                  NaN
# 726  Percentage of currently married or in union wo...                  NaN
# 727                                                NaN                  NaN
#
#                                             Unnamed: 3  \
# 0                                                  NaN
# 1                                                  NaN
# 2    Family planning use decisionmaking mainly by wife
# 3                                                 15.9
# 4                                                 25.2
# ..                                                 ...
# 723                                                NaN
# 724                                                NaN
# 725                                                NaN
# 726                                                NaN
# 727                                                NaN
#
#                                             Unnamed: 4         Unnamed: 5  \
# 0                                                  NaN                NaN
# 1                                                  NaN                NaN
# 2    Family planning non-use decisionmaking mainly ...  LivWell own house
# 3                                                 19.5                NaN
# 4                                                 20.9              75.94
# ..                                                 ...                ...
# 723                                                NaN                NaN
# 724                                                NaN                NaN
# 725                                                NaN                NaN
# 726                                                NaN                NaN
# 727                                                NaN                NaN
#
#                      Unnamed: 6  Unnamed: 7               Unnamed: 8  \
# 0                           NaN         NaN                      NaN
# 1                           NaN         NaN                      NaN
# 2    Do not own a house [Women]         NaN  Do not own land [Women]
# 3                          51.5         NaN                     84.3
# 4                          24.1      100.04                     47.3
# ..                          ...         ...                      ...
# 723                         NaN         NaN                      NaN
# 724                         NaN         NaN                      NaN
# 725                         NaN         NaN                      NaN
# 726                         NaN         NaN                      NaN
# 727                         NaN         NaN                      NaN
#
#                                             Unnamed: 9  \
# 0                                                  NaN
# 1                                                  NaN
# 2    Decision maker about Own health care: Mainly w...
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 723                                                NaN
# 724                                                NaN
# 725                                                NaN
# 726                                                NaN
# 727                                                NaN
#
#                                            Unnamed: 10  \
# 0                                                  NaN
# 1                                                  NaN
# 2    Decision maker about Major household purchases...
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 723                                                NaN
# 724                                                NaN
# 725                                                NaN
# 726                                                NaN
# 727                                                NaN
#
#                                            Unnamed: 11  \
# 0                                                  NaN
# 1                                                  NaN
# 2    Decision maker about Visits to her family or r...
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 723                                                NaN
# 724                                                NaN
# 725                                                NaN
# 726                                                NaN
# 727                                                NaN
#
#                               Unnamed: 12  \
# 0                                     NaN
# 1                                     NaN
# 2    Final say in own health care [Women]
# 3                                      96
# 4                                    97.9
# ..                                    ...
# 723                                   NaN
# 724                                   NaN
# 725                                   NaN
# 726                                   NaN
# 727                                   NaN
#
#                                      Unnamed: 13  \
# 0                                            NaN
# 1                                            NaN
# 2    Final say in making large purchases [Women]
# 3                                           80.3
# 4                                           89.9
# ..                                           ...
# 723                                          NaN
# 724                                          NaN
# 725                                          NaN
# 726                                          NaN
# 727                                          NaN
#
#                                            Unnamed: 14  \
# 0                                                  NaN
# 1                                                  NaN
# 2    Final say in visits to family, relatives, frie...
# 3                                                 92.3
# 4                                                 85.8
# ..                                                 ...
# 723                                                NaN
# 724                                                NaN
# 725                                                NaN
# 726                                                NaN
# 727                                                NaN
#
#                                            Unnamed: 15  \
# 0                                                  NaN
# 1                                                  NaN
# 2    Women who decide themselves how their earnings...
# 3                                                 27.8
# 4                                                   24
# ..                                                 ...
# 723                                                NaN
# 724                                                NaN
# 725                                                NaN
# 726                                                NaN
# 727                                                NaN
#
#                       Unnamed: 16
# 0                             NaN
# 1                             NaN
# 2    Wife earns more than husband
# 3                             8.3
# 4                            15.5
# ..                            ...
# 723                           NaN
# 724                           NaN
# 725                           NaN
# 726                           NaN
# 727                           NaN
#
# [728 rows x 17 columns]

# %% [markdown]
# 🤔 How many rows are null?  Can we safely skip them?
#
# * Top 2 rows are null and we want the third row to be for titles.
# * Bottom rows are not regional data.

# %%
stat_power.iloc[0].isnull().sum()
# Out:
# np.int64(17)

# %%
# Check out the tail end.  Rows 714-727 are not regional data.
stat_power.tail(15)
# Out:
#                                             Unnamed: 0  \
# 713                                               Togo
# 714                                                NaN
# 715  Family planning use decisionmaking mainly by wife
# 716  Family planning non-use decisionmaking mainly ...
# 717                         Do not own a house [Women]
# 718                            Do not own land [Women]
# 719  Decision maker about Own health care: Mainly w...
# 720  Decision maker about Major household purchases...
# 721  Decision maker about Visits to her family or r...
# 722               Final say in own health care [Women]
# 723        Final say in making large purchases [Women]
# 724  Final say in visits to family, relatives, frie...
# 725  Women who decide themselves how their earnings...
# 726                       Wife earns more than husband
# 727  ICF, 2015. The DHS Program STATcompiler. Funde...
#
#                                             Unnamed: 1  \
# 713                                        2013-14 DHS
# 714                                                NaN
# 715  Among currently married women using family pla...
# 716  Among currently married women not currently us...
# 717         Percentage of women who do not own a house
# 718            Percentage of women who do not own land
# 719  Percentage of women for whom the decision make...
# 720  Percentage of women for whom the decision make...
# 721  Percentage of women for whom the decision make...
# 722  Percentage of women who say that they alone or...
# 723  Percentage of women who say that they alone or...
# 724  Percentage of women who say that they alone or...
# 725  Percentage of currently married or in union wo...
# 726  Percentage of currently married or in union wo...
# 727                                                NaN
#
#                                        Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 713  Decision : Visits to her family or relatives        NaN        NaN
# 714                                           NaN        NaN        NaN
# 715                                           NaN        NaN        NaN
# 716                                           NaN        NaN        NaN
# 717                                           NaN        NaN        NaN
# 718                                           NaN        NaN        NaN
# 719                                           NaN        NaN        NaN
# 720                                           NaN        NaN        NaN
# 721                                           NaN        NaN        NaN
# 722                                           NaN        NaN        NaN
# 723                                           NaN        NaN        NaN
# 724                                           NaN        NaN        NaN
# 725                                           NaN        NaN        NaN
# 726                                           NaN        NaN        NaN
# 727                                           NaN        NaN        NaN
#
#     Unnamed: 5 Unnamed: 6  Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10  \
# 713        NaN        NaN         NaN        NaN        NaN         NaN
# 714        NaN        NaN         NaN        NaN        NaN         NaN
# 715        NaN        NaN         NaN        NaN        NaN         NaN
# 716        NaN        NaN         NaN        NaN        NaN         NaN
# 717        NaN        NaN         NaN        NaN        NaN         NaN
# 718        NaN        NaN         NaN        NaN        NaN         NaN
# 719        NaN        NaN         NaN        NaN        NaN         NaN
# 720        NaN        NaN         NaN        NaN        NaN         NaN
# 721        NaN        NaN         NaN        NaN        NaN         NaN
# 722        NaN        NaN         NaN        NaN        NaN         NaN
# 723        NaN        NaN         NaN        NaN        NaN         NaN
# 724        NaN        NaN         NaN        NaN        NaN         NaN
# 725        NaN        NaN         NaN        NaN        NaN         NaN
# 726        NaN        NaN         NaN        NaN        NaN         NaN
# 727        NaN        NaN         NaN        NaN        NaN         NaN
#
#     Unnamed: 11 Unnamed: 12 Unnamed: 13 Unnamed: 14 Unnamed: 15 Unnamed: 16
# 713        17.4         NaN         NaN         NaN         NaN         NaN
# 714         NaN         NaN         NaN         NaN         NaN         NaN
# 715         NaN         NaN         NaN         NaN         NaN         NaN
# 716         NaN         NaN         NaN         NaN         NaN         NaN
# 717         NaN         NaN         NaN         NaN         NaN         NaN
# 718         NaN         NaN         NaN         NaN         NaN         NaN
# 719         NaN         NaN         NaN         NaN         NaN         NaN
# 720         NaN         NaN         NaN         NaN         NaN         NaN
# 721         NaN         NaN         NaN         NaN         NaN         NaN
# 722         NaN         NaN         NaN         NaN         NaN         NaN
# 723         NaN         NaN         NaN         NaN         NaN         NaN
# 724         NaN         NaN         NaN         NaN         NaN         NaN
# 725         NaN         NaN         NaN         NaN         NaN         NaN
# 726         NaN         NaN         NaN         NaN         NaN         NaN
# 727         NaN         NaN         NaN         NaN         NaN         NaN

# %%
# Read the file again by skipping the top NaN rows and bottom rows
stat_power = pd.read_csv(stat_decision_power_file, skiprows=3, skipfooter=14, engine='python')
stat_power
# Out:
#      Country       Survey                                Characteristic  \
# 0    Armenia  2015-16 DHS                                         Total
# 1    Armenia  2015-16 DHS                           Region : Aragatsotn
# 2    Armenia  2015-16 DHS                               Region : Ararat
# 3    Armenia  2015-16 DHS                              Region : Armavir
# 4    Armenia  2015-16 DHS                          Region : Gegharkunik
# ..       ...          ...                                           ...
# 706     Togo  2013-14 DHS                                 Region : Kara
# 707     Togo  2013-14 DHS                              Region : Savanes
# 708     Togo  2013-14 DHS                    Decision : Own health care
# 709     Togo  2013-14 DHS          Decision : Major household purchases
# 710     Togo  2013-14 DHS  Decision : Visits to her family or relatives
#
#      Family planning use decisionmaking mainly by wife  \
# 0                                                 15.9
# 1                                                 25.2
# 2                                                 13.2
# 3                                                  7.0
# 4                                                 12.9
# ..                                                 ...
# 706                                               28.5
# 707                                               30.9
# 708                                                NaN
# 709                                                NaN
# 710                                                NaN
#
#      Family planning non-use decisionmaking mainly by wife  LivWell own house  \
# 0                                                 19.5                    NaN
# 1                                                 20.9                  75.94
# 2                                                  6.9                  69.42
# 3                                                 15.3                  22.96
# 4                                                 24.7                  80.78
# ..                                                 ...                    ...
# 706                                                NaN                    NaN
# 707                                                NaN                    NaN
# 708                                                NaN                    NaN
# 709                                                NaN                    NaN
# 710                                                NaN                    NaN
#
#      Do not own a house [Women]  Unnamed: 7  Do not own land [Women]  \
# 0                          51.5         NaN                     84.3
# 1                          24.1      100.04                     47.3
# 2                          30.6      100.02                     63.7
# 3                          77.0       99.96                     90.3
# 4                          19.2       99.98                     38.2
# ..                          ...         ...                      ...
# 706                        89.9         NaN                     92.4
# 707                        83.8         NaN                     86.6
# 708                         NaN         NaN                      NaN
# 709                         NaN         NaN                      NaN
# 710                         NaN         NaN                      NaN
#
#      Decision maker about Own health care: Mainly wife [Women]  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 706                                                NaN
# 707                                                NaN
# 708                                               11.6
# 709                                                NaN
# 710                                                NaN
#
#      Decision maker about Major household purchases: Mainly wife [Women]  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 706                                                NaN
# 707                                                NaN
# 708                                                NaN
# 709                                               14.3
# 710                                                NaN
#
#      Decision maker about Visits to her family or relatives: Mainly wife [Women]  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 706                                                NaN
# 707                                                NaN
# 708                                                NaN
# 709                                                NaN
# 710                                               17.4
#
#      Final say in own health care [Women]  \
# 0                                    96.0
# 1                                    97.9
# 2                                    87.0
# 3                                    99.2
# 4                                    88.1
# ..                                    ...
# 706                                  42.4
# 707                                  41.0
# 708                                   NaN
# 709                                   NaN
# 710                                   NaN
#
#      Final say in making large purchases [Women]  \
# 0                                           80.3
# 1                                           89.9
# 2                                           53.6
# 3                                           90.8
# 4                                           62.4
# ..                                           ...
# 706                                         41.2
# 707                                         46.4
# 708                                          NaN
# 709                                          NaN
# 710                                          NaN
#
#      Final say in visits to family, relatives, friends [Women]  \
# 0                                                 92.3
# 1                                                 85.8
# 2                                                 81.2
# 3                                                 97.9
# 4                                                 81.4
# ..                                                 ...
# 706                                               66.4
# 707                                               63.4
# 708                                                NaN
# 709                                                NaN
# 710                                                NaN
#
#      Women who decide themselves how their earnings are used  \
# 0                                                 27.8
# 1                                                 24.0
# 2                                                 13.0
# 3                                                 41.3
# 4                                                 20.0
# ..                                                 ...
# 706                                               96.4
# 707                                               84.4
# 708                                                NaN
# 709                                                NaN
# 710                                                NaN
#
#      Wife earns more than husband
# 0                             8.3
# 1                            15.5
# 2                             8.1
# 3                             5.8
# 4                             4.7
# ..                            ...
# 706                           8.1
# 707                           5.8
# 708                           NaN
# 709                           NaN
# 710                           NaN
#
# [711 rows x 17 columns]

# %%
set(stat_power['Country'])
# Out:
# {'Armenia',
#  'Congo Democratic Republic',
#  'Ethiopia',
#  'Lesotho',
#  'Malawi',
#  'Maldives',
#  'Mozambique',
#  'Namibia',
#  'Nepal',
#  'Nicaragua',
#  'Nigeria',
#  'Rwanda',
#  'Tajikistan',
#  'Timor-Leste',
#  'Togo'}

# %%
# Look at the length of this list
len(set(stat_power['Country']))
# Out:
# 15

# %% [markdown]
# ## One country example
#
# * Get data for just Armenia
# * Make a deep `.copy()` so you are not operating on a view and avoid the <a href="https://realpython.com/pandas-settingwithcopywarning/">`SettingWithCopyWarning`</a>

# %%
stat_armenia_power = stat_power[stat_power['Country'] == 'Armenia'].copy()
stat_armenia_power.head(15)
# Out:
#     Country       Survey                                Characteristic  \
# 0   Armenia  2015-16 DHS                                         Total
# 1   Armenia  2015-16 DHS                           Region : Aragatsotn
# 2   Armenia  2015-16 DHS                               Region : Ararat
# 3   Armenia  2015-16 DHS                              Region : Armavir
# 4   Armenia  2015-16 DHS                          Region : Gegharkunik
# 5   Armenia  2015-16 DHS                                 Region : Lori
# 6   Armenia  2015-16 DHS                               Region : Kotayk
# 7   Armenia  2015-16 DHS                               Region : Shirak
# 8   Armenia  2015-16 DHS                               Region : Syunik
# 9   Armenia  2015-16 DHS                          Region : Vayots Dzor
# 10  Armenia  2015-16 DHS                               Region : Tavush
# 11  Armenia  2015-16 DHS                              Region : Yerevan
# 12  Armenia  2015-16 DHS                    Decision : Own health care
# 13  Armenia  2015-16 DHS          Decision : Major household purchases
# 14  Armenia  2015-16 DHS  Decision : Visits to her family or relatives
#
#     Family planning use decisionmaking mainly by wife  \
# 0                                                15.9
# 1                                                25.2
# 2                                                13.2
# 3                                                 7.0
# 4                                                12.9
# 5                                                 9.1
# 6                                                16.9
# 7                                                11.2
# 8                                                 0.0
# 9                                                12.0
# 10                                               13.2
# 11                                               23.1
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
#
#     Family planning non-use decisionmaking mainly by wife  LivWell own house  \
# 0                                                19.5                    NaN
# 1                                                20.9                  75.94
# 2                                                 6.9                  69.42
# 3                                                15.3                  22.96
# 4                                                24.7                  80.78
# 5                                                 5.5                  55.49
# 6                                                36.7                  49.56
# 7                                                23.6                  19.78
# 8                                                 7.1                  55.72
# 9                                                12.2                  51.36
# 10                                               23.5                  37.62
# 11                                               19.4                  44.25
# 12                                                NaN                    NaN
# 13                                                NaN                    NaN
# 14                                                NaN                    NaN
#
#     Do not own a house [Women]  Unnamed: 7  Do not own land [Women]  \
# 0                         51.5         NaN                     84.3
# 1                         24.1      100.04                     47.3
# 2                         30.6      100.02                     63.7
# 3                         77.0       99.96                     90.3
# 4                         19.2       99.98                     38.2
# 5                         44.5       99.99                     99.4
# 6                         50.4       99.96                     87.2
# 7                         80.2       99.98                     96.3
# 8                         44.3      100.02                     84.2
# 9                         48.6       99.96                     85.0
# 10                        62.4      100.02                     82.9
# 11                        55.7       99.95                     98.5
# 12                         NaN         NaN                      NaN
# 13                         NaN         NaN                      NaN
# 14                         NaN         NaN                      NaN
#
#     Decision maker about Own health care: Mainly wife [Women]  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                               28.0
# 13                                                NaN
# 14                                                NaN
#
#     Decision maker about Major household purchases: Mainly wife [Women]  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                               13.6
# 14                                                NaN
#
#     Decision maker about Visits to her family or relatives: Mainly wife [Women]  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                               12.5
#
#     Final say in own health care [Women]  \
# 0                                   96.0
# 1                                   97.9
# 2                                   87.0
# 3                                   99.2
# 4                                   88.1
# 5                                   99.1
# 6                                   98.2
# 7                                   98.5
# 8                                   92.9
# 9                                   97.8
# 10                                  96.1
# 11                                  97.4
# 12                                   NaN
# 13                                   NaN
# 14                                   NaN
#
#     Final say in making large purchases [Women]  \
# 0                                          80.3
# 1                                          89.9
# 2                                          53.6
# 3                                          90.8
# 4                                          62.4
# 5                                          76.1
# 6                                          80.7
# 7                                          84.2
# 8                                          92.1
# 9                                          90.7
# 10                                         82.7
# 11                                         84.4
# 12                                          NaN
# 13                                          NaN
# 14                                          NaN
#
#     Final say in visits to family, relatives, friends [Women]  \
# 0                                                92.3
# 1                                                85.8
# 2                                                81.2
# 3                                                97.9
# 4                                                81.4
# 5                                                96.7
# 6                                                95.4
# 7                                                94.2
# 8                                                89.2
# 9                                                95.4
# 10                                               94.6
# 11                                               95.0
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
#
#     Women who decide themselves how their earnings are used  \
# 0                                                27.8
# 1                                                24.0
# 2                                                13.0
# 3                                                41.3
# 4                                                20.0
# 5                                                16.5
# 6                                                29.1
# 7                                                36.7
# 8                                                17.7
# 9                                                23.6
# 10                                               22.9
# 11                                               32.8
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
#
#     Wife earns more than husband
# 0                            8.3
# 1                           15.5
# 2                            8.1
# 3                            5.8
# 4                            4.7
# 5                           14.3
# 6                            2.8
# 7                           17.9
# 8                            7.2
# 9                           10.8
# 10                          11.5
# 11                           9.3
# 12                           NaN
# 13                           NaN
# 14                           NaN

# %%
stat_armenia_power.columns
# Out:
# Index(['Country', 'Survey', 'Characteristic',
#        'Family planning use decisionmaking mainly by wife',
#        'Family planning non-use decisionmaking mainly by wife',
#        'LivWell own house', 'Do not own a house [Women]', 'Unnamed: 7',
#        'Do not own land [Women]',
#        'Decision maker about Own health care: Mainly wife [Women]',
#        'Decision maker about Major household purchases: Mainly wife [Women]',
#        'Decision maker about Visits to her family or relatives: Mainly wife [Women]',
#        'Final say in own health care [Women]',
#        'Final say in making large purchases [Women]',
#        'Final say in visits to family, relatives, friends [Women]',
#        'Women who decide themselves how their earnings are used',
#        'Wife earns more than husband'],
#       dtype='object')

# %% [markdown]
# ## 🦋 Transform data step by step
# Find columns that could be in a more useful format.

# %% [markdown]
# ### Get the survey years
# Take out the space between the year and the survey name.

# %%
set(stat_armenia_power['Survey'])
# Out:
# {'2000 DHS', '2005 DHS', '2010 DHS', '2015-16 DHS'}

# %%
# Split the survey year text on the space ' ' to get the year.
# Make two new columns 'year_text' and 'source' that appear at the right side.
stat_armenia_power[['year','source']] = stat_armenia_power.loc[:, 'Survey'].str.split(expand=True)
stat_armenia_power.head(15)
# Out:
#     Country       Survey                                Characteristic  \
# 0   Armenia  2015-16 DHS                                         Total
# 1   Armenia  2015-16 DHS                           Region : Aragatsotn
# 2   Armenia  2015-16 DHS                               Region : Ararat
# 3   Armenia  2015-16 DHS                              Region : Armavir
# 4   Armenia  2015-16 DHS                          Region : Gegharkunik
# 5   Armenia  2015-16 DHS                                 Region : Lori
# 6   Armenia  2015-16 DHS                               Region : Kotayk
# 7   Armenia  2015-16 DHS                               Region : Shirak
# 8   Armenia  2015-16 DHS                               Region : Syunik
# 9   Armenia  2015-16 DHS                          Region : Vayots Dzor
# 10  Armenia  2015-16 DHS                               Region : Tavush
# 11  Armenia  2015-16 DHS                              Region : Yerevan
# 12  Armenia  2015-16 DHS                    Decision : Own health care
# 13  Armenia  2015-16 DHS          Decision : Major household purchases
# 14  Armenia  2015-16 DHS  Decision : Visits to her family or relatives
#
#     Family planning use decisionmaking mainly by wife  \
# 0                                                15.9
# 1                                                25.2
# 2                                                13.2
# 3                                                 7.0
# 4                                                12.9
# 5                                                 9.1
# 6                                                16.9
# 7                                                11.2
# 8                                                 0.0
# 9                                                12.0
# 10                                               13.2
# 11                                               23.1
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
#
#     Family planning non-use decisionmaking mainly by wife  LivWell own house  \
# 0                                                19.5                    NaN
# 1                                                20.9                  75.94
# 2                                                 6.9                  69.42
# 3                                                15.3                  22.96
# 4                                                24.7                  80.78
# 5                                                 5.5                  55.49
# 6                                                36.7                  49.56
# 7                                                23.6                  19.78
# 8                                                 7.1                  55.72
# 9                                                12.2                  51.36
# 10                                               23.5                  37.62
# 11                                               19.4                  44.25
# 12                                                NaN                    NaN
# 13                                                NaN                    NaN
# 14                                                NaN                    NaN
#
#     Do not own a house [Women]  Unnamed: 7  Do not own land [Women]  \
# 0                         51.5         NaN                     84.3
# 1                         24.1      100.04                     47.3
# 2                         30.6      100.02                     63.7
# 3                         77.0       99.96                     90.3
# 4                         19.2       99.98                     38.2
# 5                         44.5       99.99                     99.4
# 6                         50.4       99.96                     87.2
# 7                         80.2       99.98                     96.3
# 8                         44.3      100.02                     84.2
# 9                         48.6       99.96                     85.0
# 10                        62.4      100.02                     82.9
# 11                        55.7       99.95                     98.5
# 12                         NaN         NaN                      NaN
# 13                         NaN         NaN                      NaN
# 14                         NaN         NaN                      NaN
#
#     Decision maker about Own health care: Mainly wife [Women]  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                               28.0
# 13                                                NaN
# 14                                                NaN
#
#     Decision maker about Major household purchases: Mainly wife [Women]  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                               13.6
# 14                                                NaN
#
#     Decision maker about Visits to her family or relatives: Mainly wife [Women]  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                               12.5
#
#     Final say in own health care [Women]  \
# 0                                   96.0
# 1                                   97.9
# 2                                   87.0
# 3                                   99.2
# 4                                   88.1
# 5                                   99.1
# 6                                   98.2
# 7                                   98.5
# 8                                   92.9
# 9                                   97.8
# 10                                  96.1
# 11                                  97.4
# 12                                   NaN
# 13                                   NaN
# 14                                   NaN
#
#     Final say in making large purchases [Women]  \
# 0                                          80.3
# 1                                          89.9
# 2                                          53.6
# 3                                          90.8
# 4                                          62.4
# 5                                          76.1
# 6                                          80.7
# 7                                          84.2
# 8                                          92.1
# 9                                          90.7
# 10                                         82.7
# 11                                         84.4
# 12                                          NaN
# 13                                          NaN
# 14                                          NaN
#
#     Final say in visits to family, relatives, friends [Women]  \
# 0                                                92.3
# 1                                                85.8
# 2                                                81.2
# 3                                                97.9
# 4                                                81.4
# 5                                                96.7
# 6                                                95.4
# 7                                                94.2
# 8                                                89.2
# 9                                                95.4
# 10                                               94.6
# 11                                               95.0
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
#
#     Women who decide themselves how their earnings are used  \
# 0                                                27.8
# 1                                                24.0
# 2                                                13.0
# 3                                                41.3
# 4                                                20.0
# 5                                                16.5
# 6                                                29.1
# 7                                                36.7
# 8                                                17.7
# 9                                                23.6
# 10                                               22.9
# 11                                               32.8
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
#
#     Wife earns more than husband     year source
# 0                            8.3  2015-16    DHS
# 1                           15.5  2015-16    DHS
# 2                            8.1  2015-16    DHS
# 3                            5.8  2015-16    DHS
# 4                            4.7  2015-16    DHS
# 5                           14.3  2015-16    DHS
# 6                            2.8  2015-16    DHS
# 7                           17.9  2015-16    DHS
# 8                            7.2  2015-16    DHS
# 9                           10.8  2015-16    DHS
# 10                          11.5  2015-16    DHS
# 11                           9.3  2015-16    DHS
# 12                           NaN  2015-16    DHS
# 13                           NaN  2015-16    DHS
# 14                           NaN  2015-16    DHS

# %%
### Rename the year text 2015-16 to 2016.
stat_armenia_power['year'] = stat_armenia_power['year'].replace('2015-16', '2016')
stat_armenia_power.head()
# Out:
#    Country       Survey        Characteristic  \
# 0  Armenia  2015-16 DHS                 Total
# 1  Armenia  2015-16 DHS   Region : Aragatsotn
# 2  Armenia  2015-16 DHS       Region : Ararat
# 3  Armenia  2015-16 DHS      Region : Armavir
# 4  Armenia  2015-16 DHS  Region : Gegharkunik
#
#    Family planning use decisionmaking mainly by wife  \
# 0                                               15.9
# 1                                               25.2
# 2                                               13.2
# 3                                                7.0
# 4                                               12.9
#
#    Family planning non-use decisionmaking mainly by wife  LivWell own house  \
# 0                                               19.5                    NaN
# 1                                               20.9                  75.94
# 2                                                6.9                  69.42
# 3                                               15.3                  22.96
# 4                                               24.7                  80.78
#
#    Do not own a house [Women]  Unnamed: 7  Do not own land [Women]  \
# 0                        51.5         NaN                     84.3
# 1                        24.1      100.04                     47.3
# 2                        30.6      100.02                     63.7
# 3                        77.0       99.96                     90.3
# 4                        19.2       99.98                     38.2
#
#    Decision maker about Own health care: Mainly wife [Women]  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Decision maker about Major household purchases: Mainly wife [Women]  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Decision maker about Visits to her family or relatives: Mainly wife [Women]  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Final say in own health care [Women]  \
# 0                                  96.0
# 1                                  97.9
# 2                                  87.0
# 3                                  99.2
# 4                                  88.1
#
#    Final say in making large purchases [Women]  \
# 0                                         80.3
# 1                                         89.9
# 2                                         53.6
# 3                                         90.8
# 4                                         62.4
#
#    Final say in visits to family, relatives, friends [Women]  \
# 0                                               92.3
# 1                                               85.8
# 2                                               81.2
# 3                                               97.9
# 4                                               81.4
#
#    Women who decide themselves how their earnings are used  \
# 0                                               27.8
# 1                                               24.0
# 2                                               13.0
# 3                                               41.3
# 4                                               20.0
#
#    Wife earns more than husband  year source
# 0                           8.3  2016    DHS
# 1                          15.5  2016    DHS
# 2                           8.1  2016    DHS
# 3                           5.8  2016    DHS
# 4                           4.7  2016    DHS

# %%
# Similarly, split the region using by the colin " : "
stat_armenia_power['region'] = stat_armenia_power.loc[:, 'Characteristic'].str.split(" : ").str[1]
stat_armenia_power.head()
# Out:
#    Country       Survey        Characteristic  \
# 0  Armenia  2015-16 DHS                 Total
# 1  Armenia  2015-16 DHS   Region : Aragatsotn
# 2  Armenia  2015-16 DHS       Region : Ararat
# 3  Armenia  2015-16 DHS      Region : Armavir
# 4  Armenia  2015-16 DHS  Region : Gegharkunik
#
#    Family planning use decisionmaking mainly by wife  \
# 0                                               15.9
# 1                                               25.2
# 2                                               13.2
# 3                                                7.0
# 4                                               12.9
#
#    Family planning non-use decisionmaking mainly by wife  LivWell own house  \
# 0                                               19.5                    NaN
# 1                                               20.9                  75.94
# 2                                                6.9                  69.42
# 3                                               15.3                  22.96
# 4                                               24.7                  80.78
#
#    Do not own a house [Women]  Unnamed: 7  Do not own land [Women]  \
# 0                        51.5         NaN                     84.3
# 1                        24.1      100.04                     47.3
# 2                        30.6      100.02                     63.7
# 3                        77.0       99.96                     90.3
# 4                        19.2       99.98                     38.2
#
#    Decision maker about Own health care: Mainly wife [Women]  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Decision maker about Major household purchases: Mainly wife [Women]  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Decision maker about Visits to her family or relatives: Mainly wife [Women]  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Final say in own health care [Women]  \
# 0                                  96.0
# 1                                  97.9
# 2                                  87.0
# 3                                  99.2
# 4                                  88.1
#
#    Final say in making large purchases [Women]  \
# 0                                         80.3
# 1                                         89.9
# 2                                         53.6
# 3                                         90.8
# 4                                         62.4
#
#    Final say in visits to family, relatives, friends [Women]  \
# 0                                               92.3
# 1                                               85.8
# 2                                               81.2
# 3                                               97.9
# 4                                               81.4
#
#    Women who decide themselves how their earnings are used  \
# 0                                               27.8
# 1                                               24.0
# 2                                               13.0
# 3                                               41.3
# 4                                               20.0
#
#    Wife earns more than husband  year source       region
# 0                           8.3  2016    DHS          NaN
# 1                          15.5  2016    DHS   Aragatsotn
# 2                           8.1  2016    DHS       Ararat
# 3                           5.8  2016    DHS      Armavir
# 4                           4.7  2016    DHS  Gegharkunik

# %% [markdown]
# ### Drop rows that are not regions
# 📌 Tip: I like to name new dataframes when I've done significant operations like dropping rows.  This avoids errors if I re-run cells.

# %%
# Drop rows that are not regions
stat_armenia_power = stat_armenia_power[~stat_armenia_power['Characteristic'].str.contains('Total')]
stat_armenia_power.head()
# Out:
#    Country       Survey        Characteristic  \
# 1  Armenia  2015-16 DHS   Region : Aragatsotn
# 2  Armenia  2015-16 DHS       Region : Ararat
# 3  Armenia  2015-16 DHS      Region : Armavir
# 4  Armenia  2015-16 DHS  Region : Gegharkunik
# 5  Armenia  2015-16 DHS         Region : Lori
#
#    Family planning use decisionmaking mainly by wife  \
# 1                                               25.2
# 2                                               13.2
# 3                                                7.0
# 4                                               12.9
# 5                                                9.1
#
#    Family planning non-use decisionmaking mainly by wife  LivWell own house  \
# 1                                               20.9                  75.94
# 2                                                6.9                  69.42
# 3                                               15.3                  22.96
# 4                                               24.7                  80.78
# 5                                                5.5                  55.49
#
#    Do not own a house [Women]  Unnamed: 7  Do not own land [Women]  \
# 1                        24.1      100.04                     47.3
# 2                        30.6      100.02                     63.7
# 3                        77.0       99.96                     90.3
# 4                        19.2       99.98                     38.2
# 5                        44.5       99.99                     99.4
#
#    Decision maker about Own health care: Mainly wife [Women]  \
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
#
#    Decision maker about Major household purchases: Mainly wife [Women]  \
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
#
#    Decision maker about Visits to her family or relatives: Mainly wife [Women]  \
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
#
#    Final say in own health care [Women]  \
# 1                                  97.9
# 2                                  87.0
# 3                                  99.2
# 4                                  88.1
# 5                                  99.1
#
#    Final say in making large purchases [Women]  \
# 1                                         89.9
# 2                                         53.6
# 3                                         90.8
# 4                                         62.4
# 5                                         76.1
#
#    Final say in visits to family, relatives, friends [Women]  \
# 1                                               85.8
# 2                                               81.2
# 3                                               97.9
# 4                                               81.4
# 5                                               96.7
#
#    Women who decide themselves how their earnings are used  \
# 1                                               24.0
# 2                                               13.0
# 3                                               41.3
# 4                                               20.0
# 5                                               16.5
#
#    Wife earns more than husband  year source       region
# 1                          15.5  2016    DHS   Aragatsotn
# 2                           8.1  2016    DHS       Ararat
# 3                           5.8  2016    DHS      Armavir
# 4                           4.7  2016    DHS  Gegharkunik
# 5                          14.3  2016    DHS         Lori

# %%
# Rename dataframe
stat_armenia_pow = stat_armenia_power.drop(columns=['Survey', 'Characteristic'])
stat_armenia_pow.head()
# Out:
#    Country  Family planning use decisionmaking mainly by wife  \
# 1  Armenia                                               25.2
# 2  Armenia                                               13.2
# 3  Armenia                                                7.0
# 4  Armenia                                               12.9
# 5  Armenia                                                9.1
#
#    Family planning non-use decisionmaking mainly by wife  LivWell own house  \
# 1                                               20.9                  75.94
# 2                                                6.9                  69.42
# 3                                               15.3                  22.96
# 4                                               24.7                  80.78
# 5                                                5.5                  55.49
#
#    Do not own a house [Women]  Unnamed: 7  Do not own land [Women]  \
# 1                        24.1      100.04                     47.3
# 2                        30.6      100.02                     63.7
# 3                        77.0       99.96                     90.3
# 4                        19.2       99.98                     38.2
# 5                        44.5       99.99                     99.4
#
#    Decision maker about Own health care: Mainly wife [Women]  \
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
#
#    Decision maker about Major household purchases: Mainly wife [Women]  \
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
#
#    Decision maker about Visits to her family or relatives: Mainly wife [Women]  \
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
#
#    Final say in own health care [Women]  \
# 1                                  97.9
# 2                                  87.0
# 3                                  99.2
# 4                                  88.1
# 5                                  99.1
#
#    Final say in making large purchases [Women]  \
# 1                                         89.9
# 2                                         53.6
# 3                                         90.8
# 4                                         62.4
# 5                                         76.1
#
#    Final say in visits to family, relatives, friends [Women]  \
# 1                                               85.8
# 2                                               81.2
# 3                                               97.9
# 4                                               81.4
# 5                                               96.7
#
#    Women who decide themselves how their earnings are used  \
# 1                                               24.0
# 2                                               13.0
# 3                                               41.3
# 4                                               20.0
# 5                                               16.5
#
#    Wife earns more than husband  year source       region
# 1                          15.5  2016    DHS   Aragatsotn
# 2                           8.1  2016    DHS       Ararat
# 3                           5.8  2016    DHS      Armavir
# 4                           4.7  2016    DHS  Gegharkunik
# 5                          14.3  2016    DHS         Lori

# %%
# Rename education columns
rename_DP_cols = {
    'Country' : 'country_name',
    'Wife earns more than husband' : 'DP_earn_more_p',
    'Women who decide themselves how their earnings are used' : 'DP_decide_money_p',
    'Do not own a house [Women]' : 'STAT_not_homeowner'
}

# %%
stat_armenia_DP = stat_armenia_pow.rename(columns=rename_DP_cols)
stat_armenia_DP.head()
# Out:
#   country_name  Family planning use decisionmaking mainly by wife  \
# 1      Armenia                                               25.2
# 2      Armenia                                               13.2
# 3      Armenia                                                7.0
# 4      Armenia                                               12.9
# 5      Armenia                                                9.1
#
#    Family planning non-use decisionmaking mainly by wife  LivWell own house  \
# 1                                               20.9                  75.94
# 2                                                6.9                  69.42
# 3                                               15.3                  22.96
# 4                                               24.7                  80.78
# 5                                                5.5                  55.49
#
#    STAT_not_homeowner  Unnamed: 7  Do not own land [Women]  \
# 1                24.1      100.04                     47.3
# 2                30.6      100.02                     63.7
# 3                77.0       99.96                     90.3
# 4                19.2       99.98                     38.2
# 5                44.5       99.99                     99.4
#
#    Decision maker about Own health care: Mainly wife [Women]  \
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
#
#    Decision maker about Major household purchases: Mainly wife [Women]  \
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
#
#    Decision maker about Visits to her family or relatives: Mainly wife [Women]  \
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
#
#    Final say in own health care [Women]  \
# 1                                  97.9
# 2                                  87.0
# 3                                  99.2
# 4                                  88.1
# 5                                  99.1
#
#    Final say in making large purchases [Women]  \
# 1                                         89.9
# 2                                         53.6
# 3                                         90.8
# 4                                         62.4
# 5                                         76.1
#
#    Final say in visits to family, relatives, friends [Women]  \
# 1                                               85.8
# 2                                               81.2
# 3                                               97.9
# 4                                               81.4
# 5                                               96.7
#
#    DP_decide_money_p  DP_earn_more_p  year source       region
# 1               24.0            15.5  2016    DHS   Aragatsotn
# 2               13.0             8.1  2016    DHS       Ararat
# 3               41.3             5.8  2016    DHS      Armavir
# 4               20.0             4.7  2016    DHS  Gegharkunik
# 5               16.5            14.3  2016    DHS         Lori

# %% [markdown]
# ### Choose and reorder columns
# Now the year and regions look like the LivWell data set.

# %%
stat_armenia_DP = stat_armenia_DP[['country_name', 'year', 'region', 'DP_earn_more_p', 'DP_decide_money_p', 'STAT_not_homeowner']]
stat_armenia_DP.head()
# Out:
#   country_name  year       region  DP_earn_more_p  DP_decide_money_p  \
# 1      Armenia  2016   Aragatsotn            15.5               24.0
# 2      Armenia  2016       Ararat             8.1               13.0
# 3      Armenia  2016      Armavir             5.8               41.3
# 4      Armenia  2016  Gegharkunik             4.7               20.0
# 5      Armenia  2016         Lori            14.3               16.5
#
#    STAT_not_homeowner
# 1                24.1
# 2                30.6
# 3                77.0
# 4                19.2
# 5                44.5

# %% [markdown]
# ## 👍  Now this looks similar to our LivWell data set.
# * Survey years are numbers (not `2015-2016 DHS`)
# * Regions are just names (no `' : '`)
# * Renamed columns of interest

# %% [markdown]
# ## Filter LivWell columns to match STAT columns
# Choose only the dataa we need.
#
# ### Get LivWell Aremnia decision and power columns
# Make it a list.

# %%
# These are all of the LivWell (lw) decision and power (DP) columns
lw_all_pow_cols = livwell_armenia.columns[livwell_armenia.columns.str.contains('DP')].to_list()
lw_all_pow_cols
# Out:
# ['DP_decide_money_p',
#  'DP_decide_money_p_se',
#  'DP_decide_health_p',
#  'DP_decide_health_p_se',
#  'DP_decide_large_purchase_p',
#  'DP_decide_large_purchase_p_se',
#  'DP_decide_visits_p',
#  'DP_decide_visits_p_se',
#  'DP_owns_house_p',
#  'DP_owns_house_p_se',
#  'DP_owns_land_p',
#  'DP_owns_land_p_se',
#  'DP_decide_contraception_p',
#  'DP_decide_contraception_p_se',
#  'DP_decide_no_contraception_p',
#  'DP_decide_no_contraception_p_se',
#  'DP_earn_more_equal_p',
#  'DP_earn_more_equal_p_se',
#  'DP_earn_more_p',
#  'DP_earn_more_p_se']

# %%
# Choose columns of interest
lw_DP_cols = ['country_name', 'country_code', 'year', 'region_num_harmonized',
       'region_name_harmonized', 'DP_earn_more_p', 'DP_owns_house_p','DP_decide_money_p']

# %%
# LivWell data for general and power columns
livwell_armenia_DP = livwell_armenia[lw_DP_cols]
livwell_armenia_DP
# Out:
#    country_name country_code  year  region_num_harmonized  \
# 0       Armenia          ARM  2000                      1
# 1       Armenia          ARM  2000                      2
# 2       Armenia          ARM  2000                      3
# 3       Armenia          ARM  2000                      4
# 4       Armenia          ARM  2000                      5
# 5       Armenia          ARM  2000                      6
# 6       Armenia          ARM  2000                      7
# 7       Armenia          ARM  2000                      8
# 8       Armenia          ARM  2000                      9
# 9       Armenia          ARM  2000                     10
# 10      Armenia          ARM  2000                     11
# 11      Armenia          ARM  2005                      1
# 12      Armenia          ARM  2005                      2
# 13      Armenia          ARM  2005                      3
# 14      Armenia          ARM  2005                      4
# 15      Armenia          ARM  2005                      5
# 16      Armenia          ARM  2005                      6
# 17      Armenia          ARM  2005                      7
# 18      Armenia          ARM  2005                      8
# 19      Armenia          ARM  2005                      9
# 20      Armenia          ARM  2005                     10
# 21      Armenia          ARM  2005                     11
# 22      Armenia          ARM  2010                      1
# 23      Armenia          ARM  2010                      2
# 24      Armenia          ARM  2010                      3
# 25      Armenia          ARM  2010                      4
# 26      Armenia          ARM  2010                      5
# 27      Armenia          ARM  2010                      6
# 28      Armenia          ARM  2010                      7
# 29      Armenia          ARM  2010                      8
# 30      Armenia          ARM  2010                      9
# 31      Armenia          ARM  2010                     10
# 32      Armenia          ARM  2010                     11
# 33      Armenia          ARM  2016                      1
# 34      Armenia          ARM  2016                      2
# 35      Armenia          ARM  2016                      3
# 36      Armenia          ARM  2016                      4
# 37      Armenia          ARM  2016                      5
# 38      Armenia          ARM  2016                      6
# 39      Armenia          ARM  2016                      7
# 40      Armenia          ARM  2016                      8
# 41      Armenia          ARM  2016                      9
# 42      Armenia          ARM  2016                     10
# 43      Armenia          ARM  2016                     11
#
#    region_name_harmonized  DP_earn_more_p  DP_owns_house_p  DP_decide_money_p
# 0              Aragatsotn             NaN              NaN              28.00
# 1                  Ararat             NaN              NaN              30.91
# 2                 Armavir             NaN              NaN              32.81
# 3             Gegharkunik             NaN              NaN               9.62
# 4                    Lori             NaN              NaN              35.29
# 5                  Kotayk             NaN              NaN              49.28
# 6                  Shirak             NaN              NaN              28.95
# 7                  Syunik             NaN              NaN              32.97
# 8             Vayots Dzor             NaN              NaN              36.36
# 9                  Tavush             NaN              NaN              32.53
# 10                Yerevan             NaN              NaN              42.60
# 11             Aragatsotn             NaN              NaN              24.89
# 12                 Ararat             NaN              NaN               6.53
# 13                Armavir             NaN              NaN              13.37
# 14            Gegharkunik             NaN              NaN              15.38
# 15                   Lori             NaN              NaN              10.59
# 16                 Kotayk             NaN              NaN              21.64
# 17                 Shirak             NaN              NaN              22.72
# 18                 Syunik             NaN              NaN              36.59
# 19            Vayots Dzor             NaN              NaN              11.08
# 20                 Tavush             NaN              NaN              20.25
# 21                Yerevan             NaN              NaN              28.86
# 22             Aragatsotn           11.12            80.97               2.73
# 23                 Ararat            3.49            97.43               0.52
# 24                Armavir            8.57            65.75              17.07
# 25            Gegharkunik           12.52            98.43               5.63
# 26                   Lori            7.97            75.10              27.93
# 27                 Kotayk            4.89            95.06              28.68
# 28                 Shirak           10.20            79.21              24.01
# 29                 Syunik            4.12            70.86              12.61
# 30            Vayots Dzor           15.43            25.50              35.33
# 31                 Tavush           10.35            78.54              34.75
# 32                Yerevan           11.94            54.07              40.51
# 33             Aragatsotn           15.99            75.94              23.97
# 34                 Ararat            8.39            69.42              13.00
# 35                Armavir            8.08            22.96              41.33
# 36            Gegharkunik            7.26            80.78              19.97
# 37                   Lori           20.22            55.49              16.53
# 38                 Kotayk            3.55            49.56              29.12
# 39                 Shirak           19.08            19.78              36.74
# 40                 Syunik            7.64            55.72              17.74
# 41            Vayots Dzor           12.03            51.36              23.57
# 42                 Tavush           15.61            37.62              22.88
# 43                Yerevan           10.50            44.25              32.81

# %%
# Ckeck our columns for our datasets
print(stat_armenia_DP.columns)
print(livwell_armenia_DP.columns)
# Out:
# Index(['country_name', 'year', 'region', 'DP_earn_more_p', 'DP_decide_money_p',
#        'STAT_not_homeowner'],
#       dtype='object')
# Index(['country_name', 'country_code', 'year', 'region_num_harmonized',
#        'region_name_harmonized', 'DP_earn_more_p', 'DP_owns_house_p',
#        'DP_decide_money_p'],
#       dtype='object')

# %% [markdown]
# ## Get data in the same format to merge on year and region.

# %%
# In the LivWell data, the year data is of type int
livwell_armenia_DP['year'].dtype
# Out:
# dtype('int64')

# %%
# In the STAT data, the year data is of type object
stat_armenia_DP['year'].dtypes
# Out:
# dtype('O')

# %%
# Recast the year as an int.  We need to do this to prevent a
# ValueError: You are trying to merge on object and int64 columns for key 'year'
stat_armenia_DP['year'] = stat_armenia_DP['year'].astype(int)
stat_armenia_DP['year'].dtype
# Out:
# dtype('int64')

# %% [markdown]
# ## 🧩 Merge the data!
#
# Choose which variables should be the same.
# * On the left (STAT data) those are `country_name`, `region`, and `year`.
# * On the right (LivWell data) those are `country_name`, `region_name_harmonized` and `year`.
# * For the columns that are the same, the new column names will have a suffix (`_stat, `_lw`) to differentiate.

# %%
merged_df = stat_armenia_DP.merge(livwell_armenia_DP, left_on=['country_name', 'region', 'year'],
            right_on=['country_name', 'region_name_harmonized', 'year'],
            suffixes=('_stat', '_lw'))

merged_df.columns
# Out:
# Index(['country_name', 'year', 'region', 'DP_earn_more_p_stat',
#        'DP_decide_money_p_stat', 'STAT_not_homeowner', 'country_code',
#        'region_num_harmonized', 'region_name_harmonized', 'DP_earn_more_p_lw',
#        'DP_owns_house_p', 'DP_decide_money_p_lw'],
#       dtype='object')

# %%
merged_df
# Out:
#    country_name  year       region  DP_earn_more_p_stat  \
# 0       Armenia  2016   Aragatsotn                 15.5
# 1       Armenia  2016       Ararat                  8.1
# 2       Armenia  2016      Armavir                  5.8
# 3       Armenia  2016  Gegharkunik                  4.7
# 4       Armenia  2016         Lori                 14.3
# 5       Armenia  2016       Kotayk                  2.8
# 6       Armenia  2016       Shirak                 17.9
# 7       Armenia  2016       Syunik                  7.2
# 8       Armenia  2016  Vayots Dzor                 10.8
# 9       Armenia  2016       Tavush                 11.5
# 10      Armenia  2016      Yerevan                  9.3
# 11      Armenia  2010   Aragatsotn                  7.7
# 12      Armenia  2010       Ararat                  2.8
# 13      Armenia  2010      Armavir                  5.1
# 14      Armenia  2010  Gegharkunik                 11.9
# 15      Armenia  2010         Lori                  7.4
# 16      Armenia  2010       Kotayk                  4.5
# 17      Armenia  2010       Shirak                 10.0
# 18      Armenia  2010       Syunik                  4.0
# 19      Armenia  2010  Vayots Dzor                  9.7
# 20      Armenia  2010       Tavush                  9.9
# 21      Armenia  2010      Yerevan                 10.8
# 22      Armenia  2005   Aragatsotn                  NaN
# 23      Armenia  2005       Ararat                  NaN
# 24      Armenia  2005      Armavir                  NaN
# 25      Armenia  2005  Gegharkunik                  NaN
# 26      Armenia  2005         Lori                  NaN
# 27      Armenia  2005       Kotayk                  NaN
# 28      Armenia  2005       Shirak                  NaN
# 29      Armenia  2005       Syunik                  NaN
# 30      Armenia  2005  Vayots Dzor                  NaN
# 31      Armenia  2005       Tavush                  NaN
# 32      Armenia  2005      Yerevan                  NaN
# 33      Armenia  2000   Aragatsotn                  NaN
# 34      Armenia  2000       Ararat                  NaN
# 35      Armenia  2000      Armavir                  NaN
# 36      Armenia  2000  Gegharkunik                  NaN
# 37      Armenia  2000         Lori                  NaN
# 38      Armenia  2000       Kotayk                  NaN
# 39      Armenia  2000       Shirak                  NaN
# 40      Armenia  2000       Syunik                  NaN
# 41      Armenia  2000  Vayots Dzor                  NaN
# 42      Armenia  2000       Tavush                  NaN
# 43      Armenia  2000      Yerevan                  NaN
#
#     DP_decide_money_p_stat  STAT_not_homeowner country_code  \
# 0                     24.0                24.1          ARM
# 1                     13.0                30.6          ARM
# 2                     41.3                77.0          ARM
# 3                     20.0                19.2          ARM
# 4                     16.5                44.5          ARM
# 5                     29.1                50.4          ARM
# 6                     36.7                80.2          ARM
# 7                     17.7                44.3          ARM
# 8                     23.6                48.6          ARM
# 9                     22.9                62.4          ARM
# 10                    32.8                55.7          ARM
# 11                     2.7                19.0          ARM
# 12                     0.5                 2.6          ARM
# 13                    17.1                34.3          ARM
# 14                     5.6                 1.6          ARM
# 15                    27.9                24.7          ARM
# 16                    28.7                 4.9          ARM
# 17                    24.0                20.8          ARM
# 18                    12.6                29.1          ARM
# 19                    35.3                74.5          ARM
# 20                    34.8                21.5          ARM
# 21                    40.5                45.9          ARM
# 22                    24.9                 NaN          ARM
# 23                     6.5                 NaN          ARM
# 24                    13.4                 NaN          ARM
# 25                    15.4                 NaN          ARM
# 26                    10.6                 NaN          ARM
# 27                    21.6                 NaN          ARM
# 28                    22.7                 NaN          ARM
# 29                    36.6                 NaN          ARM
# 30                    11.1                 NaN          ARM
# 31                    20.2                 NaN          ARM
# 32                    28.9                 NaN          ARM
# 33                    28.0                 NaN          ARM
# 34                    30.9                 NaN          ARM
# 35                    32.8                 NaN          ARM
# 36                     9.6                 NaN          ARM
# 37                    35.3                 NaN          ARM
# 38                    49.3                 NaN          ARM
# 39                    28.9                 NaN          ARM
# 40                    33.0                 NaN          ARM
# 41                    36.4                 NaN          ARM
# 42                    32.5                 NaN          ARM
# 43                    42.6                 NaN          ARM
#
#     region_num_harmonized region_name_harmonized  DP_earn_more_p_lw  \
# 0                       1             Aragatsotn              15.99
# 1                       2                 Ararat               8.39
# 2                       3                Armavir               8.08
# 3                       4            Gegharkunik               7.26
# 4                       5                   Lori              20.22
# 5                       6                 Kotayk               3.55
# 6                       7                 Shirak              19.08
# 7                       8                 Syunik               7.64
# 8                       9            Vayots Dzor              12.03
# 9                      10                 Tavush              15.61
# 10                     11                Yerevan              10.50
# 11                      1             Aragatsotn              11.12
# 12                      2                 Ararat               3.49
# 13                      3                Armavir               8.57
# 14                      4            Gegharkunik              12.52
# 15                      5                   Lori               7.97
# 16                      6                 Kotayk               4.89
# 17                      7                 Shirak              10.20
# 18                      8                 Syunik               4.12
# 19                      9            Vayots Dzor              15.43
# 20                     10                 Tavush              10.35
# 21                     11                Yerevan              11.94
# 22                      1             Aragatsotn                NaN
# 23                      2                 Ararat                NaN
# 24                      3                Armavir                NaN
# 25                      4            Gegharkunik                NaN
# 26                      5                   Lori                NaN
# 27                      6                 Kotayk                NaN
# 28                      7                 Shirak                NaN
# 29                      8                 Syunik                NaN
# 30                      9            Vayots Dzor                NaN
# 31                     10                 Tavush                NaN
# 32                     11                Yerevan                NaN
# 33                      1             Aragatsotn                NaN
# 34                      2                 Ararat                NaN
# 35                      3                Armavir                NaN
# 36                      4            Gegharkunik                NaN
# 37                      5                   Lori                NaN
# 38                      6                 Kotayk                NaN
# 39                      7                 Shirak                NaN
# 40                      8                 Syunik                NaN
# 41                      9            Vayots Dzor                NaN
# 42                     10                 Tavush                NaN
# 43                     11                Yerevan                NaN
#
#     DP_owns_house_p  DP_decide_money_p_lw
# 0             75.94                 23.97
# 1             69.42                 13.00
# 2             22.96                 41.33
# 3             80.78                 19.97
# 4             55.49                 16.53
# 5             49.56                 29.12
# 6             19.78                 36.74
# 7             55.72                 17.74
# 8             51.36                 23.57
# 9             37.62                 22.88
# 10            44.25                 32.81
# 11            80.97                  2.73
# 12            97.43                  0.52
# 13            65.75                 17.07
# 14            98.43                  5.63
# 15            75.10                 27.93
# 16            95.06                 28.68
# 17            79.21                 24.01
# 18            70.86                 12.61
# 19            25.50                 35.33
# 20            78.54                 34.75
# 21            54.07                 40.51
# 22              NaN                 24.89
# 23              NaN                  6.53
# 24              NaN                 13.37
# 25              NaN                 15.38
# 26              NaN                 10.59
# 27              NaN                 21.64
# 28              NaN                 22.72
# 29              NaN                 36.59
# 30              NaN                 11.08
# 31              NaN                 20.25
# 32              NaN                 28.86
# 33              NaN                 28.00
# 34              NaN                 30.91
# 35              NaN                 32.81
# 36              NaN                  9.62
# 37              NaN                 35.29
# 38              NaN                 49.28
# 39              NaN                 28.95
# 40              NaN                 32.97
# 41              NaN                 36.36
# 42              NaN                 32.53
# 43              NaN                 42.60

# %% [markdown]
# And hopefully they match!   Reorder columns to get a better look.
#
# For example does `DP_earn_more_p_lw` match `DP_earn_more_p_stat`?
#
# Note that `STAT_owns_house_p` is the inverse of `STAT_not_homeowner`.
#
# 🔎 More to explore
# * Can you check to see that `STAT_owns_house_p` and `STAT_not_homeowner` add up to 100%?
# * Can you upload other STAT files to compare to LivWell?

# %%
merged_df[['country_name', 'year', 'region', 'DP_earn_more_p_lw', 'DP_earn_more_p_stat',
           'DP_decide_money_p_lw', 'DP_decide_money_p_stat',
           'DP_owns_house_p', 'STAT_not_homeowner']]
# Out:
#    country_name  year       region  DP_earn_more_p_lw  DP_earn_more_p_stat  \
# 0       Armenia  2016   Aragatsotn              15.99                 15.5
# 1       Armenia  2016       Ararat               8.39                  8.1
# 2       Armenia  2016      Armavir               8.08                  5.8
# 3       Armenia  2016  Gegharkunik               7.26                  4.7
# 4       Armenia  2016         Lori              20.22                 14.3
# 5       Armenia  2016       Kotayk               3.55                  2.8
# 6       Armenia  2016       Shirak              19.08                 17.9
# 7       Armenia  2016       Syunik               7.64                  7.2
# 8       Armenia  2016  Vayots Dzor              12.03                 10.8
# 9       Armenia  2016       Tavush              15.61                 11.5
# 10      Armenia  2016      Yerevan              10.50                  9.3
# 11      Armenia  2010   Aragatsotn              11.12                  7.7
# 12      Armenia  2010       Ararat               3.49                  2.8
# 13      Armenia  2010      Armavir               8.57                  5.1
# 14      Armenia  2010  Gegharkunik              12.52                 11.9
# 15      Armenia  2010         Lori               7.97                  7.4
# 16      Armenia  2010       Kotayk               4.89                  4.5
# 17      Armenia  2010       Shirak              10.20                 10.0
# 18      Armenia  2010       Syunik               4.12                  4.0
# 19      Armenia  2010  Vayots Dzor              15.43                  9.7
# 20      Armenia  2010       Tavush              10.35                  9.9
# 21      Armenia  2010      Yerevan              11.94                 10.8
# 22      Armenia  2005   Aragatsotn                NaN                  NaN
# 23      Armenia  2005       Ararat                NaN                  NaN
# 24      Armenia  2005      Armavir                NaN                  NaN
# 25      Armenia  2005  Gegharkunik                NaN                  NaN
# 26      Armenia  2005         Lori                NaN                  NaN
# 27      Armenia  2005       Kotayk                NaN                  NaN
# 28      Armenia  2005       Shirak                NaN                  NaN
# 29      Armenia  2005       Syunik                NaN                  NaN
# 30      Armenia  2005  Vayots Dzor                NaN                  NaN
# 31      Armenia  2005       Tavush                NaN                  NaN
# 32      Armenia  2005      Yerevan                NaN                  NaN
# 33      Armenia  2000   Aragatsotn                NaN                  NaN
# 34      Armenia  2000       Ararat                NaN                  NaN
# 35      Armenia  2000      Armavir                NaN                  NaN
# 36      Armenia  2000  Gegharkunik                NaN                  NaN
# 37      Armenia  2000         Lori                NaN                  NaN
# 38      Armenia  2000       Kotayk                NaN                  NaN
# 39      Armenia  2000       Shirak                NaN                  NaN
# 40      Armenia  2000       Syunik                NaN                  NaN
# 41      Armenia  2000  Vayots Dzor                NaN                  NaN
# 42      Armenia  2000       Tavush                NaN                  NaN
# 43      Armenia  2000      Yerevan                NaN                  NaN
#
#     DP_decide_money_p_lw  DP_decide_money_p_stat  DP_owns_house_p  \
# 0                  23.97                    24.0            75.94
# 1                  13.00                    13.0            69.42
# 2                  41.33                    41.3            22.96
# 3                  19.97                    20.0            80.78
# 4                  16.53                    16.5            55.49
# 5                  29.12                    29.1            49.56
# 6                  36.74                    36.7            19.78
# 7                  17.74                    17.7            55.72
# 8                  23.57                    23.6            51.36
# 9                  22.88                    22.9            37.62
# 10                 32.81                    32.8            44.25
# 11                  2.73                     2.7            80.97
# 12                  0.52                     0.5            97.43
# 13                 17.07                    17.1            65.75
# 14                  5.63                     5.6            98.43
# 15                 27.93                    27.9            75.10
# 16                 28.68                    28.7            95.06
# 17                 24.01                    24.0            79.21
# 18                 12.61                    12.6            70.86
# 19                 35.33                    35.3            25.50
# 20                 34.75                    34.8            78.54
# 21                 40.51                    40.5            54.07
# 22                 24.89                    24.9              NaN
# 23                  6.53                     6.5              NaN
# 24                 13.37                    13.4              NaN
# 25                 15.38                    15.4              NaN
# 26                 10.59                    10.6              NaN
# 27                 21.64                    21.6              NaN
# 28                 22.72                    22.7              NaN
# 29                 36.59                    36.6              NaN
# 30                 11.08                    11.1              NaN
# 31                 20.25                    20.2              NaN
# 32                 28.86                    28.9              NaN
# 33                 28.00                    28.0              NaN
# 34                 30.91                    30.9              NaN
# 35                 32.81                    32.8              NaN
# 36                  9.62                     9.6              NaN
# 37                 35.29                    35.3              NaN
# 38                 49.28                    49.3              NaN
# 39                 28.95                    28.9              NaN
# 40                 32.97                    33.0              NaN
# 41                 36.36                    36.4              NaN
# 42                 32.53                    32.5              NaN
# 43                 42.60                    42.6              NaN
#
#     STAT_not_homeowner
# 0                 24.1
# 1                 30.6
# 2                 77.0
# 3                 19.2
# 4                 44.5
# 5                 50.4
# 6                 80.2
# 7                 44.3
# 8                 48.6
# 9                 62.4
# 10                55.7
# 11                19.0
# 12                 2.6
# 13                34.3
# 14                 1.6
# 15                24.7
# 16                 4.9
# 17                20.8
# 18                29.1
# 19                74.5
# 20                21.5
# 21                45.9
# 22                 NaN
# 23                 NaN
# 24                 NaN
# 25                 NaN
# 26                 NaN
# 27                 NaN
# 28                 NaN
# 29                 NaN
# 30                 NaN
# 31                 NaN
# 32                 NaN
# 33                 NaN
# 34                 NaN
# 35                 NaN
# 36                 NaN
# 37                 NaN
# 38                 NaN
# 39                 NaN
# 40                 NaN
# 41                 NaN
# 42                 NaN
# 43                 NaN

# %% [markdown]
# # 🎉 Tada!
# We have used Python code to match the validation data to the LivWell data set.

# %% [markdown]
# # 🗺️ More to explore
#
# The authors incorporated many  approaches in their work including:
#
# * Analysis in R.  Check out their <a href="https://gitlab.pik-potsdam.de/belmin/livwelldata">LivWell R repository</a>. They linearly interpolated data using the R package `imputeTS`.
# * Collapsed categories for <a href="https://gitlab.pik-potsdam.de/belmin/livwelldata-paper/-/blob/main/analysis/data/raw_data/all_labels_cooking_fuel_completed_coal_as_traditional.csv?ref_type=heads">modern and traditional cooking fuel</a>
#   * Modern: electricity, liquefied
# petroleum gas, natural gas, kerosene and biogas
#   * Traditional: biomass (firewood, charcoal, agricultural crops, coal)
#   * This could also be described as recoding, label encoding, or feature engineering
# * Recoded drinking water quality to low, medium, high quality.
# * <a href="https://gitlab.pik-potsdam.de/belmin/livwelldata-paper/-/blob/main/analysis/data/derived_data/region_harmonization_files/dhs_region_harmonization.csv?ref_type=heads">Geographic data</a>. The authors harmonized variables over time and across countries.

# %% [markdown]
# # 🔑 Takeaways
# * Learn the context of the data.
# * Before transforming, have a target usage and format in mind.
# * You don't need to know all the syntax.  Practice!
